# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagovillamizarjaimes-collab/programacion1/blob/main/Tarea_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Listas
Lista = [29, True, 3.1415, "El numero de avogadro sí que mola"]
print(Lista)
# Out:
# [29, True, 3.1415, 'El numero de avogadro sí que mola']

# %%
print(Lista[0])
# Out:
# 29
